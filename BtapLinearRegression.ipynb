# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielBinh2k3/BTVN_Lab1/blob/main/BtapLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = np.array([[1, 1], [2, 3], [3, 2], [4, 4], [5, 4]])
print(X)
#Ex1:a)	Tính MSE với model y = 2x+1. 
#MSE
def MSE(y_true, y_predicted):
  mse = ((y_true - y_predicted)**2).mean(axis=0)
  return mse
# Model y = 2x + 1
x1 = X[:, 0]
y_true = X[:, 1]
y_predicted = 2*x1 + 1
print(MSE(y_true, y_predicted))
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_true, y_predicted))
# Out:
# [[1 1]
#  [2 3]
#  [3 2]
#  [4 4]
#  [5 4]]
# 21.4
# 21.4

# %%
#b)	Cho nhập a, b tính MSE với model y = ax+b. 
a, b = int(input("Pleasea enter the value of a: ")), int(input("Pleasea enter the value of b: "))
y_predicted = a * x1 + b
print(MSE(y_true, y_predicted))
print(mean_squared_error(y_true, y_predicted))
# Out:
# Pleasea enter the value of a: 3
# Pleasea enter the value of b: 4
# 115.0
# 115.0

# %%
#c)	Dùng thư viện sklearn tìm model linear regerssion phù hợp nhất, in ra các hệ số coefficient, intercep của model. Tính MSE, score 
plt.scatter(x1, y_true)
reg = LinearRegression().fit(x1.reshape(-1, 1), y_true)
plt.plot(x1, reg.predict(x1.reshape(-1, 1)))
print(reg.score(x1.reshape(-1, 1), y_true))
print(reg.coef_)
print(reg.intercept_)
print(reg.predict([[1]]))
y_predicted = reg.coef_[0] * x1 + reg.intercept_ 
print(MSE(y_true, y_predicted))
# Out:
# 0.7205882352941175
# [0.7]
# 0.7000000000000002
# [1.4]
# 0.3800000000000001

# %%
#Ex2: a)	Visualize dữ liệu dạng scatter.

# %%
df = pd.read_csv("./drive/MyDrive/ColabNotebooks/data_linear.csv")
df.head()
# Out:
#    Diện tích      Giá
# 0    30.0000  448.524
# 1    32.4138  509.248
# 2    34.8276  535.104
# 3    37.2414  551.432
# 4    39.6552  623.418

# %%
y = df[['Giá']]
X = df[['Diện tích']]
import matplotlib as mpl
mpl.style.use('classic')
plt.scatter(X, y)
X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size =0.1)

# %%
reg = LinearRegression().fit(X_train, y_train)
print(reg.score(X_train, y_train))
print(reg.coef_)
print(reg.intercept_)
print(reg.predict([[1]]))
x2 = X.to_numpy()
y_predicted = reg.coef_[0] * x2 + reg.intercept_ 
print(MSE(y, y_predicted))
plt.scatter(X, y)
plt.plot(X, reg.predict(X))
print(reg.score(X_test,y_test))
# Out:
# 0.9973537803780702
# [[15.19699821]]
# [-5.5105269]
# [[9.68647131]]
# Giá    247.113258
# dtype: float64
# 0.9994639494340575
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
print(reg.predict([[50]]))
print(reg.predict([[120]]))
print(reg.predict([[150]]))
# Out:
# [[753.49027134]]
# [[1818.26662732]]
# [[2274.59935131]]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
plt.scatter(X, y, color = "red")
plt.plot(X, reg.predict(X), color = "black")

# %%
# EX3:

# %%
df1 = pd.read_csv("./drive/MyDrive/ColabNotebooks/data_square.csv")
df1.head()
# Out:
#    Diện tích  Giá nhà
# 0    30.0000 -100.000
# 1    32.4138 -190.725
# 2    34.8276 -269.798
# 3    37.2414 -337.218
# 4    39.6552 -392.985

# %%
X = df1[['Diện tích']]
X.to_numpy().reshape(-1,1)
# Out:
# array([[ 30.    ],
#        [ 32.4138],
#        [ 34.8276],
#        [ 37.2414],
#        [ 39.6552],
#        [ 42.069 ],
#        [ 44.4828],
#        [ 46.8966],
#        [ 49.3103],
#        [ 51.7241],
#        [ 54.1379],
#        [ 56.5517],
#        [ 58.9655],
#        [ 61.3793],
#        [ 63.7931],
#        [ 66.2069],
#        [ 68.6207],
#        [ 71.0345],
#        [ 73.4483],
#        [ 75.8621],
#        [ 78.2759],
#        [ 80.6897],
#        [ 83.1034],
#        [ 85.5172],
#        [ 87.931 ],
#        [ 90.3448],
#        [ 92.7586],
#        [ 95.1724],
#        [ 97.5862],
#        [100.    ]])

# %%
X = df1[['Diện tích']]
y = df1[['Giá nhà']]
import matplotlib as mpl
mpl.style.use('classic')
plt.scatter(X, y)
X = X.to_numpy()
y = y.to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size =0.1)
X_train
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-8ee1b9c34a33> in <module>()
#       6 X = X.to_numpy()
#       7 y = y.to_numpy()
# ----> 8 X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size =0.1)
#       9 X_train
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(X.reshape(-1, 1))
poly_features
# Out:
# array([[   30.        ,   900.        ],
#        [   32.4138    ,  1050.65443044],
#        [   34.8276    ,  1212.96172176],
#        [   37.2414    ,  1386.92187396],
#        [   39.6552    ,  1572.53488704],
#        [   42.069     ,  1769.800761  ],
#        [   44.4828    ,  1978.71949584],
#        [   46.8966    ,  2199.29109156],
#        [   49.3103    ,  2431.50568609],
#        [   51.7241    ,  2675.38252081],
#        [   54.1379    ,  2930.91221641],
#        [   56.5517    ,  3198.09477289],
#        [   58.9655    ,  3476.93019025],
#        [   61.3793    ,  3767.41846849],
#        [   63.7931    ,  4069.55960761],
#        [   66.2069    ,  4383.35360761],
#        [   68.6207    ,  4708.80046849],
#        [   71.0345    ,  5045.90019025],
#        [   73.4483    ,  5394.65277289],
#        [   75.8621    ,  5755.05821641],
#        [   78.2759    ,  6127.11652081],
#        [   80.6897    ,  6510.82768609],
#        [   83.1034    ,  6906.17509156],
# ...

# %%
poly_reg_model = LinearRegression()
poly_reg_model = poly_reg_model.fit(poly_features, y)
y_predicted = poly_reg_model.predict(poly_features)
coeff = poly_reg_model.coef_
intercept = poly_reg_model.intercept_
# y_res = intercept + coeff[0] * X_train + coeff[1] * X_train**2

plt.figure(figsize=(10, 6))
plt.title("polynomial regression", size=16)
plt.scatter(X, y)
plt.plot(X, y, c="red") # sap xep lại :)))

plt.show()
